# %% [markdown]
# ## Importing Packages

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #### Helper Functions

# %%
def detect_outliers(column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_limit = Q1 - 1.5*IQR
    upper_limit = Q3 + 1.5*IQR
    outliers = (data[column] < lower_limit) | (data[column] > upper_limit)
    return outliers

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Reading the CSV File

# %%
data = pd.read_csv("first inten project.csv")
data.head()
# Out:
#   Booking_ID  number of adults  number of children  number of weekend nights  \
# 0   INN00001                 1                   1                         2
# 1   INN00002                 1                   0                         1
# 2   INN00003                 2                   1                         1
# 3   INN00004                 1                   0                         0
# 4   INN00005                 1                   0                         1
#
#    number of week nights  type of meal  car parking space    room type  \
# 0                      5   Meal Plan 1                  0  Room_Type 1
# 1                      3  Not Selected                  0  Room_Type 1
# 2                      3   Meal Plan 1                  0  Room_Type 1
# 3                      2   Meal Plan 1                  0  Room_Type 1
# 4                      2  Not Selected                  0  Room_Type 1
#
#    lead time market segment type  repeated  P-C  P-not-C  average price   \
# 0        224             Offline         0    0        0           88.00
# 1          5              Online         0    0        0          106.68
# 2          1              Online         0    0        0           50.00
# 3        211              Online         0    0        0          100.00
# 4         48              Online         0    0        0           77.00
#
#    special requests date of reservation booking status
# 0                 0           10/2/2015   Not_Canceled
# 1                 1           11/6/2018   Not_Canceled
# 2                 0           2/28/2018       Canceled
# 3                 1           5/20/2017       Canceled
# 4                 0           4/11/2018       Canceled

# %%
len(data)
# Out:
# 36285

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Checking "number of adults" Feature

# %%
column = "number of adults"

# %%
data[column].describe()
# Out:
# count    36285.000000
# mean         1.844839
# std          0.518813
# min          0.000000
# 25%          2.000000
# 50%          2.000000
# 75%          2.000000
# max          4.000000
# Name: number of adults, dtype: float64

# %%
data[column].value_counts()
# Out:
# number of adults
# 2    26110
# 1     7702
# 3     2318
# 0      139
# 4       16
# Name: count, dtype: int64

# %%
null = np.sum(data[column].isnull())
print(f"There are {null} null values.")
# Out:
# There are 0 null values.

# %%
data[column].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='number of adults'>

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Checking "number of children" Feature

# %%
column = "number of children"

# %%
data[column].describe()
# Out:
# count    36285.000000
# mean         0.105360
# std          0.402704
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max         10.000000
# Name: number of children, dtype: float64

# %%
data[column].value_counts()
# Out:
# number of children
# 0     33583
# 1      1622
# 2      1058
# 3        19
# 9         2
# 10        1
# Name: count, dtype: int64

# %%
null = np.sum(data[column].isnull())
print(f"There are {null} null values.")
# Out:
# There are 0 null values.

# %%
data[column].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='number of children'>

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Checking "number of weekend nights" Feature

# %%
column = "number of weekend nights"

# %%
data[column].describe()
# Out:
# count    36285.000000
# mean         0.810693
# std          0.870590
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          2.000000
# max          7.000000
# Name: number of weekend nights, dtype: float64

# %%
data[column].value_counts()
# Out:
# number of weekend nights
# 0    16876
# 1    10000
# 2     9072
# 3      153
# 4      129
# 5       34
# 6       20
# 7        1
# Name: count, dtype: int64

# %%
null = np.sum(data[column].isnull())
print(f"There are {null} null values.")
# Out:
# There are 0 null values.

# %%
data[column].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='number of weekend nights'>

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Checking "number of week nights" Feature

# %%
column = "number of week nights"

# %%
data[column].describe()
# Out:
# count    36285.000000
# mean         2.204602
# std          1.410946
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         17.000000
# Name: number of week nights, dtype: float64

# %%
data[column].value_counts()
# Out:
# number of week nights
# 2     11447
# 1      9488
# 3      7842
# 4      2992
# 0      2387
# 5      1616
# 6       189
# 7       113
# 10       62
# 8        62
# 9        34
# 11       17
# 15       10
# 12        9
# 14        7
# 13        5
# 17        3
# 16        2
# Name: count, dtype: int64

# %%
null = np.sum(data[column].isnull())
print(f"There are {null} null values.")
# Out:
# There are 0 null values.

# %%
data[column].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='number of week nights'>

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Checking "type of meal" Feature

# %%
column = "type of meal"

# %%
data[column].describe()
# Out:
# count           36285
# unique              4
# top       Meal Plan 1
# freq            27842
# Name: type of meal, dtype: object

# %%
data[column].value_counts()
# Out:
# type of meal
# Meal Plan 1     27842
# Not Selected     5132
# Meal Plan 2      3306
# Meal Plan 3         5
# Name: count, dtype: int64

# %%
null = np.sum(data[column].isnull())
print(f"There are {null} null values.")
# Out:
# There are 0 null values.

# %%
data[column].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='type of meal'>

# %% [markdown]
# ##### Do label encoding for this categorical feature

# %%
# Not Selected ...> 0
# Meal Plan 1  ...> 1
# Meal Plan 2  ...> 2
# Meal Plan 3  ...> 3

# %%
data[column] = data[column].replace("Not Selected", 0)
data[column] = data[column].replace("Meal Plan 1", 1)
data[column] = data[column].replace("Meal Plan 2", 2)
data[column] = data[column].replace("Meal Plan 3", 3)

# %%
data[column].value_counts()
# Out:
# type of meal
# 1    27842
# 0     5132
# 2     3306
# 3        5
# Name: count, dtype: int64

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Checking "car parking space" Feature

# %%
column = "car parking space"

# %%
data[column].describe()
# Out:
# count    36285.000000
# mean         0.030977
# std          0.173258
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: car parking space, dtype: float64

# %%
data[column].value_counts()
# Out:
# car parking space
# 0    35161
# 1     1124
# Name: count, dtype: int64

# %%
null = np.sum(data[column].isnull())
print(f"There are {null} null values.")
# Out:
# There are 0 null values.

# %%
data[column].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='car parking space'>

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Checking "room type" Feature

# %%
column = "room type"

# %%
data[column].describe()
# Out:
# count           36285
# unique              7
# top       Room_Type 1
# freq            28138
# Name: room type, dtype: object

# %%
data[column].value_counts()
# Out:
# room type
# Room_Type 1    28138
# Room_Type 4     6059
# Room_Type 6      966
# Room_Type 2      692
# Room_Type 5      265
# Room_Type 7      158
# Room_Type 3        7
# Name: count, dtype: int64

# %%
null = np.sum(data[column].isnull())
print(f"There are {null} null values.")
# Out:
# There are 0 null values.

# %%
data[column].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='room type'>

# %% [markdown]
# ##### Do label encoding for this categorical feature

# %%
# Room_Type 1  ...> 0
# Room_Type 2  ...> 1
# Room_Type 3  ...> 2
# Room_Type 4  ...> 3
# Room_Type 5  ...> 4
# Room_Type 6  ...> 5
# Room_Type 7  ...> 6

# %%
data[column] = data[column].replace("Room_Type 1", 0)
data[column] = data[column].replace("Room_Type 2", 1)
data[column] = data[column].replace("Room_Type 3", 2)
data[column] = data[column].replace("Room_Type 4", 3)
data[column] = data[column].replace("Room_Type 5", 4)
data[column] = data[column].replace("Room_Type 6", 5)
data[column] = data[column].replace("Room_Type 7", 6)

# %%
data[column].value_counts()
# Out:
# room type
# 0    28138
# 3     6059
# 5      966
# 1      692
# 4      265
# 6      158
# 2        7
# Name: count, dtype: int64

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Checking "lead time" Feature

# %%
column = "lead time"

# %%
data[column].describe()
# Out:
# count    36285.000000
# mean        85.239851
# std         85.938796
# min          0.000000
# 25%         17.000000
# 50%         57.000000
# 75%        126.000000
# max        443.000000
# Name: lead time, dtype: float64

# %%
null = np.sum(data[column].isnull())
print(f"There are {null} null values.")
# Out:
# There are 0 null values.

# %%
sns.histplot(data[column], kde=False)
# Out:
# <Axes: xlabel='lead time', ylabel='Count'>

# %%
sns.boxplot(data[column], orient="h")
# Out:
# <Axes: >

# %%
outliers = detect_outliers(column)
print(f"Number of outliers:", np.sum(outliers))
# Out:
# Number of outliers: 1332

# %% [markdown]
# - I will not remove/replace the outliers because higher values for lead time may have an impact on the booking status

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Checking "market segment type" Feature

# %%
column = "market segment type"

# %%
data[column].describe()
# Out:
# count      36285
# unique         5
# top       Online
# freq       23221
# Name: market segment type, dtype: object

# %%
data[column].value_counts()
# Out:
# market segment type
# Online           23221
# Offline          10531
# Corporate         2017
# Complementary      391
# Aviation           125
# Name: count, dtype: int64

# %%
null = np.sum(data[column].isnull())
print(f"There are {null} null values.")
# Out:
# There are 0 null values.

# %%
data[column].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='market segment type'>

# %% [markdown]
# ##### Do label encoding for this categorical feature

# %%
# Online         ...> 0
# Offline        ...> 1
# Corporate      ...> 2
# Complementary  ...> 3
# Aviation       ...> 4

# %%
data[column] = data[column].replace("Online", 0)
data[column] = data[column].replace("Offline", 1)
data[column] = data[column].replace("Corporate", 2)
data[column] = data[column].replace("Complementary", 3)
data[column] = data[column].replace("Aviation", 4)

# %%
data[column].value_counts()
# Out:
# market segment type
# 0    23221
# 1    10531
# 2     2017
# 3      391
# 4      125
# Name: count, dtype: int64

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Checking "repeated" Feature

# %%
column = "repeated"

# %%
data[column].describe()
# Out:
# count    36285.000000
# mean         0.025630
# std          0.158032
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: repeated, dtype: float64

# %%
data[column].value_counts()
# Out:
# repeated
# 0    35355
# 1      930
# Name: count, dtype: int64

# %%
null = np.sum(data[column].isnull())
print(f"There are {null} null values.")
# Out:
# There are 0 null values.

# %%
data[column].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='repeated'>

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Checking "P-C" Feature

# %%
column = "P-C"

# %%
data[column].describe()
# Out:
# count    36285.000000
# mean         0.023343
# std          0.368281
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max         13.000000
# Name: P-C, dtype: float64

# %%
data[column].value_counts()
# Out:
# P-C
# 0     35947
# 1       198
# 2        46
# 3        43
# 11       25
# 5        11
# 4        10
# 13        4
# 6         1
# Name: count, dtype: int64

# %%
null = np.sum(data[column].isnull())
print(f"There are {null} null values.")
# Out:
# There are 0 null values.

# %%
data[column].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='P-C'>

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Checking "P-not-C" Feature

# %%
column = "P-not-C"

# %%
data[column].describe()
# Out:
# count    36285.000000
# mean         0.153369
# std          1.753931
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max         58.000000
# Name: P-not-C, dtype: float64

# %%
data[column].value_counts()
# Out:
# P-not-C
# 0     35473
# 1       228
# 2       112
# 3        80
# 4        65
# 5        60
# 6        36
# 7        24
# 8        23
# 10       19
# 9        19
# 11       15
# 12       12
# 14        9
# 15        8
# 16        7
# 13        7
# 18        6
# 20        6
# 21        6
# 17        6
# 19        6
# 22        6
# 25        3
# 27        3
# 24        3
# 23        3
# 44        2
# 29        2
# 48        2
# 28        2
# 30        2
# 32        2
# 31        2
# 26        2
# 46        1
# 55        1
# 45        1
# 57        1
# 53        1
# 54        1
# 58        1
# 41        1
# 40        1
# 43        1
# 35        1
# 50        1
# 56        1
# 33        1
# 37        1
# 42        1
# 51        1
# 38        1
# 34        1
# 39        1
# 52        1
# 49        1
# 47        1
# 36        1
# Name: count, dtype: int64

# %%
null = np.sum(data[column].isnull())
print(f"There are {null} null values.")
# Out:
# There are 0 null values.

# %%
#data[column].value_counts().plot(kind="bar")

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Checking "average price" Feature

# %%
column = "average price "

# %%
data[column].describe()
# Out:
# count    36285.000000
# mean       103.421636
# std         35.086469
# min          0.000000
# 25%         80.300000
# 50%         99.450000
# 75%        120.000000
# max        540.000000
# Name: average price , dtype: float64

# %%
null = np.sum(data[column].isnull())
print(f"There are {null} null values.")
# Out:
# There are 0 null values.

# %%
sns.histplot(data[column], kde=False)
# Out:
# <Axes: xlabel='average price ', ylabel='Count'>

# %%
sns.boxplot(data[column], orient="h")
# Out:
# <Axes: >

# %%
outliers = detect_outliers(column)
print(f"Number of outliers:", np.sum(outliers))
# Out:
# Number of outliers: 1696

# %% [markdown]
# - I will not remove/replace the outliers because higher values for the average price may have an impact on the booking status

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Checking "special requests" Feature

# %%
column = "special requests"

# %%
data[column].describe()
# Out:
# count    36285.000000
# mean         0.619733
# std          0.786262
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          5.000000
# Name: special requests, dtype: float64

# %%
data[column].value_counts()
# Out:
# special requests
# 0    19780
# 1    11379
# 2     4364
# 3      676
# 4       78
# 5        8
# Name: count, dtype: int64

# %%
null = np.sum(data[column].isnull())
print(f"There are {null} null values.")
# Out:
# There are 0 null values.

# %%
data[column].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='special requests'>

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Checking "booking status"

# %%
column = "booking status"

# %%
data[column].describe()
# Out:
# count            36285
# unique               2
# top       Not_Canceled
# freq             24396
# Name: booking status, dtype: object

# %%
data[column].value_counts()
# Out:
# booking status
# Not_Canceled    24396
# Canceled        11889
# Name: count, dtype: int64

# %%
null = np.sum(data[column].isnull())
print(f"There are {null} null values.")
# Out:
# There are 0 null values.

# %%
data[column].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='booking status'>

# %% [markdown]
# ##### Do label encoding for this categorical feature

# %%
# Not_Canceled  ...> 0
# Canceled      ...> 1

# %%
data[column] = data[column].replace("Not_Canceled", 0)
data[column] = data[column].replace("Canceled", 1)

# %%
data[column].value_counts()
# Out:
# booking status
# 0    24396
# 1    11889
# Name: count, dtype: int64

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Checking the relationship between Categorical Features and Average Price

# %% [markdown]
# - You may ignore this section

# %%
def plot(x, y):
    sns.stripplot(x=x, y=y, data=data, jitter=True)
    plt.xticks(rotation=45)  # Rotate x labels for better readability
    plt.show()

# %%
x = "number of adults"
y = "average price "
plot(x, y)

# %%
x = "number of children"
y = "average price "
plot(x, y)

# %%
x = "number of weekend nights"
y = "average price "
plot(x, y)

# %%
x = "number of week nights"
y = "average price "
plot(x, y)

# %%
x = "type of meal"
y = "average price "
plot(x, y)

# %%
x = "car parking space"
y = "average price "
plot(x, y)

# %%
x = "room type"
y = "average price "
plot(x, y)

# %%
x = "market segment type"
y = "average price "
plot(x, y)

# %% [markdown]
# #### Comments
# - The analysis suggests that average price does not exhibit a linear relationship with the individual categorical features examined. For instance, changes in the number of nights or the number of children do not appear to significantly affect the average price.
# - Specifically, increasing the number of nights booked or the number of children does not show a corresponding change in the average price.
# - I believe that average price may be influenced by a combination of features working together rather than any single feature individually. It is likely that the interplay between multiple variables contributes to variations in average price.

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Combining the "number of week nights" and "number of weekend nights" into one Feature

# %%
data["total nights"] = data["number of week nights"] + data["number of weekend nights"]

# %% [markdown]
# #### Adding the Feature "month" and the Feature "day" from the "date of reservation"

# %%
data["date of reservation"] = pd.to_datetime(data["date of reservation"], format="%m/%d/%Y", errors="coerce")
data["month"] = data["date of reservation"].dt.month
data["day"] = data["date of reservation"].dt.day

# %%
data.head()
# Out:
#   Booking_ID  number of adults  number of children  number of weekend nights  \
# 0   INN00001                 1                   1                         2
# 1   INN00002                 1                   0                         1
# 2   INN00003                 2                   1                         1
# 3   INN00004                 1                   0                         0
# 4   INN00005                 1                   0                         1
#
#    number of week nights  type of meal  car parking space  room type  \
# 0                      5             1                  0          0
# 1                      3             0                  0          0
# 2                      3             1                  0          0
# 3                      2             1                  0          0
# 4                      2             0                  0          0
#
#    lead time  market segment type  repeated  P-C  P-not-C  average price   \
# 0        224                    1         0    0        0           88.00
# 1          5                    0         0    0        0          106.68
# 2          1                    0         0    0        0           50.00
# 3        211                    0         0    0        0          100.00
# 4         48                    0         0    0        0           77.00
#
#    special requests date of reservation  booking status  total nights  month  \
# 0                 0          2015-10-02               0             7   10.0
# 1                 1          2018-11-06               0             4   11.0
# 2                 0          2018-02-28               1             4    2.0
# 3                 1          2017-05-20               1             2    5.0
# 4                 0          2018-04-11               1             3    4.0
#
#     day
# 0   2.0
# 1   6.0
# 2  28.0
# 3  20.0
# 4  11.0

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Dropping Unnecessary Features

# %%
data.drop(columns=["Booking_ID", "date of reservation", "number of weekend nights", "number of week nights"], inplace=True)

# %%
data.head()
# Out:
#    number of adults  number of children  type of meal  car parking space  \
# 0                 1                   1             1                  0
# 1                 1                   0             0                  0
# 2                 2                   1             1                  0
# 3                 1                   0             1                  0
# 4                 1                   0             0                  0
#
#    room type  lead time  market segment type  repeated  P-C  P-not-C  \
# 0          0        224                    1         0    0        0
# 1          0          5                    0         0    0        0
# 2          0          1                    0         0    0        0
# 3          0        211                    0         0    0        0
# 4          0         48                    0         0    0        0
#
#    average price   special requests  booking status  total nights  month   day
# 0           88.00                 0               0             7   10.0   2.0
# 1          106.68                 1               0             4   11.0   6.0
# 2           50.00                 0               1             4    2.0  28.0
# 3          100.00                 1               1             2    5.0  20.0
# 4           77.00                 0               1             3    4.0  11.0

# %% [markdown]
# # Data Analysis

# %%
# Variance
numeric_cols = data.select_dtypes(include=['int64', 'float64'])
variance_values = numeric_cols.var()

# Skewness
skewness_values = numeric_cols.skew()

# Kurtosis
kurtosis_values = numeric_cols.kurtosis()

Stat_table = pd.DataFrame({'Column': variance_values.index, 
                           'Variance': variance_values.values,
                            'Skewness': skewness_values.values,
                            'Kurtosis': kurtosis_values.values})
                         
Stat_table
# Out:
#                  Column     Variance   Skewness    Kurtosis
# 0      number of adults     0.269167  -0.332833    0.812610
# 1    number of children     0.162171   4.707675   36.947349
# 2          type of meal     0.230601  -0.130714    1.295385
# 3     car parking space     0.030018   5.414464   27.317925
# 4             room type     1.959442   1.729004    1.713485
# 5             lead time  7385.476617   1.292436    1.179155
# 6   market segment type     0.464428   1.684924    3.406882
# 7              repeated     0.024974   6.003783   34.047290
# 8                   P-C     0.135631  25.203359  732.938601
# 9               P-not-C     3.076273  19.252855  457.506897
# 10       average price   1231.060336   0.667186    3.154819
# 11     special requests     0.618208   1.145098    0.881753
# 12       booking status     0.220304   0.734411   -1.460721
# 13         total nights     3.189795   2.232199   12.226583
# 14                month     9.404063  -0.349552   -0.929616
# 15                  day    76.287644   0.029953   -1.155696

# %%
#Covariance matrix 
covar_matrix = numeric_cols.cov()
print("Covariance Matrix:\n", covar_matrix)
# Out:
# Covariance Matrix:
#                       number of adults  number of children  type of meal  \
# number of adults             0.269167           -0.004184     -0.001013
# number of children          -0.004184            0.162171      0.008167
# type of meal                -0.001013            0.008167      0.230601
# car parking space            0.001031            0.002386     -0.001261
# room type                    0.196447            0.205077      0.062791
# lead time                    4.325470           -1.628595      9.363068
# market segment type         -0.111027           -0.035824      0.083444
# repeated                    -0.015756           -0.002315      0.000759
# P-C                         -0.009056           -0.002432     -0.001202
# P-not-C                     -0.108382           -0.014974      0.005333
# average price                5.403332            4.768574      2.269527
# special requests             0.077227            0.039377     -0.034053
# booking status               0.021131            0.006239      0.011135
# total nights                 0.123832            0.024378      0.010329
# month                        0.033010           -0.003526      0.026031
# day                          0.125275            0.088687      0.065879
#
#                      car parking space  room type    lead time  \
# number of adults              0.001031   0.196447     4.325470
# number of children            0.002386   0.205077    -1.628595
# type of meal                 -0.001261   0.062791     9.363068
# car parking space             0.030018   0.009405    -0.989323
# room type                     0.009405   1.959442   -12.971674
# lead time                    -0.989323 -12.971674  7385.476617
# market segment type           0.000441  -0.149418     0.414654
# repeated                      0.003037  -0.005712    -1.846573
# P-C                           0.001730  -0.004090    -1.446951
# P-not-C                       0.019392  -0.019976   -11.775983
# average price                 0.372706  23.079082  -188.690790
# special requests              0.011973   0.159763    -6.865410
# booking status               -0.007008   0.015030    17.687284
# total nights                 -0.016624   0.255804    21.619526
# month                        -0.007981  -0.022822    35.901195
# day                          -0.000733   0.398512     5.369710
#
#                      market segment type  repeated       P-C    P-not-C  \
# number of adults               -0.111027 -0.015756 -0.009056  -0.108382
# number of children             -0.035824 -0.002315 -0.002432  -0.014974
# type of meal                    0.083444  0.000759 -0.001202   0.005333
# car parking space               0.000441  0.003037  0.001730   0.019392
# room type                      -0.149418 -0.005712 -0.004090  -0.019976
# lead time                       0.414654 -1.846573 -1.446951 -11.775983
# market segment type             0.464428  0.036375  0.018630   0.247591
# repeated                        0.036375  0.024974  0.022745   0.149442
# P-C                             0.018630  0.022745  0.135631   0.302395
# P-not-C                         0.247591  0.149442  0.302395   3.076273
# average price                  -8.980915 -0.969680 -0.818375  -6.995344
# special requests               -0.165286 -0.001470 -0.000962   0.037735
# booking status                 -0.043503 -0.007957 -0.005830  -0.049537
# total nights                   -0.185161 -0.031480 -0.022268  -0.162306
# month                           0.014511  0.000619 -0.043679  -0.055339
# day                            -0.073147 -0.023171 -0.040451  -0.028985
#
#                      average price   special requests  booking status  \
# number of adults           5.403332          0.077227        0.021131
# number of children         4.768574          0.039377        0.006239
# type of meal               2.269527         -0.034053        0.011135
# car parking space          0.372706          0.011973       -0.007008
# room type                 23.079082          0.159763        0.015030
# lead time               -188.690790         -6.865410       17.687284
# market segment type       -8.980915         -0.165286       -0.043503
# repeated                  -0.969680         -0.001470       -0.007957
# P-C                       -0.818375         -0.000962       -0.005830
# P-not-C                   -6.995344          0.037735       -0.049537
# average price           1231.060336          5.088960        2.345632
# special requests           5.088960          0.618208       -0.093402
# booking status             2.345632         -0.093402        0.220304
# total nights               0.986833          0.092549        0.086599
# month                      5.805009          0.265771       -0.017284
# day                        5.671371          0.130433        0.045898
#
#                      total nights      month        day
# number of adults         0.123832   0.033010   0.125275
# number of children       0.024378  -0.003526   0.088687
# type of meal             0.010329   0.026031   0.065879
# car parking space       -0.016624  -0.007981  -0.000733
# room type                0.255804  -0.022822   0.398512
# lead time               21.619526  35.901195   5.369710
# market segment type     -0.185161   0.014511  -0.073147
# repeated                -0.031480   0.000619  -0.023171
# P-C                     -0.022268  -0.043679  -0.040451
# P-not-C                 -0.162306  -0.055339  -0.028985
# average price            0.986833   5.805009   5.671371
# special requests         0.092549   0.265771   0.130433
# booking status           0.086599  -0.017284   0.045898
# total nights             3.189795   0.138061   0.087152
# month                    0.138061   9.404063  -1.076652
# day                      0.087152  -1.076652  76.287644

# %%
#correlation using heatmap
corr_matrix = numeric_cols.corr()
print("Correlation Matrix:\n", corr_matrix)

plt.figure(figsize=(20, 20))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title("Correlation Heatmap")
plt.show()
# Out:
# Correlation Matrix:
#                       number of adults  number of children  type of meal  \
# number of adults             1.000000           -0.020027     -0.004068
# number of children          -0.020027            1.000000      0.042233
# type of meal                -0.004068            0.042233      1.000000
# car parking space            0.011467            0.034198     -0.015154
# room type                    0.270501            0.363802      0.093411
# lead time                    0.097014           -0.047058      0.226881
# market segment type         -0.314021           -0.130536      0.254980
# repeated                    -0.192175           -0.036371      0.010003
# P-C                         -0.047395           -0.016398     -0.006796
# P-not-C                     -0.119106           -0.021201      0.006332
# average price                0.296832            0.337491      0.134699
# special requests             0.189317            0.124363     -0.090189
# booking status               0.086774            0.033007      0.049403
# total nights                 0.133641            0.033894      0.012043
# month                        0.020753           -0.002856      0.017672
# day                          0.027653            0.025221      0.015703
#
#                      car parking space  room type  lead time  \
# number of adults              0.011467   0.270501   0.097014
# number of children            0.034198   0.363802  -0.047058
# type of meal                 -0.015154   0.093411   0.226881
# car parking space             1.000000   0.038778  -0.066444
# room type                     0.038778   1.000000  -0.107830
# lead time                    -0.066444  -0.107830   1.000000
# market segment type           0.003734  -0.156631   0.007080
# repeated                      0.110916  -0.025819  -0.135966
# P-C                           0.027109  -0.007934  -0.045718
# P-not-C                       0.063814  -0.008136  -0.078126
# average price                 0.061310   0.469908  -0.062578
# special requests              0.087889   0.145159  -0.101604
# booking status               -0.086179   0.022877   0.438491
# total nights                 -0.053724   0.102320   0.140856
# month                        -0.015034  -0.005318   0.136191
# day                          -0.000485   0.032604   0.007152
#
#                      market segment type  repeated       P-C   P-not-C  \
# number of adults               -0.314021 -0.192175 -0.047395 -0.119106
# number of children             -0.130536 -0.036371 -0.016398 -0.021201
# type of meal                    0.254980  0.010003 -0.006796  0.006332
# car parking space               0.003734  0.110916  0.027109  0.063814
# room type                      -0.156631 -0.025819 -0.007934 -0.008136
# lead time                       0.007080 -0.135966 -0.045718 -0.078126
# market segment type             1.000000  0.337748  0.074228  0.207140
# repeated                        0.337748  1.000000  0.390811  0.539157
# P-C                             0.074228  0.390811  1.000000  0.468148
# P-not-C                         0.207140  0.539157  0.468148  1.000000
# average price                  -0.375597 -0.174881 -0.063334 -0.113673
# special requests               -0.308467 -0.011834 -0.003323  0.027363
# booking status                 -0.136005 -0.107277 -0.033725 -0.060174
# total nights                   -0.152128 -0.111535 -0.033854 -0.051813
# month                           0.006946  0.001279 -0.038659 -0.010293
# day                            -0.012293 -0.016814 -0.012570 -0.001893
#
#                      average price   special requests  booking status  \
# number of adults           0.296832          0.189317        0.086774
# number of children         0.337491          0.124363        0.033007
# type of meal               0.134699         -0.090189        0.049403
# car parking space          0.061310          0.087889       -0.086179
# room type                  0.469908          0.145159        0.022877
# lead time                 -0.062578         -0.101604        0.438491
# market segment type       -0.375597         -0.308467       -0.136005
# repeated                  -0.174881         -0.011834       -0.107277
# P-C                       -0.063334         -0.003323       -0.033725
# P-not-C                   -0.113673          0.027363       -0.060174
# average price              1.000000          0.184468        0.142433
# special requests           0.184468          1.000000       -0.253092
# booking status             0.142433         -0.253092        1.000000
# total nights               0.015748          0.065906        0.103305
# month                      0.053960          0.110202       -0.012007
# day                        0.018509          0.018989        0.011195
#
#                      total nights     month       day
# number of adults         0.133641  0.020753  0.027653
# number of children       0.033894 -0.002856  0.025221
# type of meal             0.012043  0.017672  0.015703
# car parking space       -0.053724 -0.015034 -0.000485
# room type                0.102320 -0.005318  0.032604
# lead time                0.140856  0.136191  0.007152
# market segment type     -0.152128  0.006946 -0.012293
# repeated                -0.111535  0.001279 -0.016814
# P-C                     -0.033854 -0.038659 -0.012570
# P-not-C                 -0.051813 -0.010293 -0.001893
# average price            0.015748  0.053960  0.018509
# special requests         0.065906  0.110202  0.018989
# booking status           0.103305 -0.012007  0.011195
# total nights             1.000000  0.025207  0.005587
# month                    0.025207  1.000000 -0.040197
# day                      0.005587 -0.040197  1.000000

# %%
data.to_excel("cleaned_data_after_eda.xlsx", index=False)

# %% [markdown]
# # Room Type and Meal Plan Demand: Highlights which room types and meal plans are most popular.

# %%
room_meal_demand = data.groupby(['room type', 'type of meal']).size().unstack()

plt.figure(figsize=(12, 8))
room_meal_demand.plot(kind='bar', stacked=True)
plt.title('Room Type and Meal Plan Demand')
plt.xlabel('Room Type')
plt.ylabel('Number of Bookings')
plt.legend(title='Meal Plan')
plt.show()

# %%
monthly_bookings = data.groupby('month').size()

plt.figure(figsize=(10, 6))
monthly_bookings.plot(kind='line', marker='o')
plt.title('Monthly Bookings Over Time')
plt.xlabel('Month')
plt.ylabel('Number of Bookings')
plt.grid(True)
plt.show()

# %%
data['is_weekend'] = data['day'].apply(lambda x: 1 if x in [6, 7] else 0)

booking_comparison = data.groupby('is_weekend').size()

plt.figure(figsize=(8, 6))
booking_comparison.plot(kind='bar', color=['skyblue', 'lightcoral'])
plt.title('Weekend vs Weekday Bookings')
plt.xlabel('Type')
plt.ylabel('Number of Bookings')
plt.xticks([0, 1], ['Weekday', 'Weekend'], rotation=0)
plt.show()
